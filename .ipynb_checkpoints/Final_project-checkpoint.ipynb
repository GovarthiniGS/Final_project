# %% [markdown]
# Loading the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv('../Final_project/data/raw/heart.csv')

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.shape
# Out:
# (1025, 14)

# %%
# To get information about our dataset like total number of rows,total number of columns,datatypes of each columns and memory requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# check for duplicate rows in the dataset
data_dup=data.duplicated().any()
print(data_dup)
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %%
# Create a copy of the DataFrame
data_copy = data.copy()

# %%
# Rename specific columns
data.rename(columns={'age': 'Age', 'sex': 'Sex','cp': 'ChestPainType','trestbps': 'Resting Blood Pressure','chol': 'Cholesterol','fbs': 'Fasting Blood Sugar','restecg': 'Resting ECG','thalach': 'Max Heart Rate','exang': 'ExerciseAngina','oldpeak': 'Oldpeak','slope': 'ST_Slope','ca': 'NumMajorVessels','thal': 'Thalassemia'}, inplace=True)
# Out:
# C:\Users\mohan\AppData\Local\Temp\ipykernel_18188\644279259.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'age': 'Age', 'sex': 'Sex','cp': 'ChestPainType','trestbps': 'Resting Blood Pressure','chol': 'Cholesterol','fbs': 'Fasting Blood Sugar','restecg': 'Resting ECG','thalach': 'Max Heart Rate','exang': 'ExerciseAngina','oldpeak': 'Oldpeak','slope': 'ST_Slope','ca': 'NumMajorVessels','thal': 'Thalassemia'}, inplace=True)

# %%
data.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   52    1              0        125          212          0           1
# 1   53    1              0        140          203          1           0
# 2   70    1              0        145          174          0           1
# 3   61    1              0        148          203          0           1
# 4   62    0              0        138          294          1           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  NumMajorVessels  Thalassemia  \
# 0    168               0      1.0         2                2            3
# 1    155               1      3.1         0                0            3
# 2    125               1      2.6         0                0            3
# 3    161               0      0.0         2                1            3
# 4    106               0      1.9         1                3            2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
data.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'NumMajorVessels', 'Thalassemia', 'target'],
#       dtype='object')

# %%
data.to_csv("../Final_project/data/clean/heart.csv", index=False)

# %%
df = pd.read_csv("../Final_project/data/clean/heart.csv")

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   52    1              0        125          212          0           1
# 1   53    1              0        140          203          1           0
# 2   70    1              0        145          174          0           1
# 3   61    1              0        148          203          0           1
# 4   62    0              0        138          294          1           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  NumMajorVessels  Thalassemia  \
# 0    168               0      1.0         2                2            3
# 1    155               1      3.1         0                0            3
# 2    125               1      2.6         0                0            3
# 3    161               0      0.0         2                1            3
# 4    106               0      1.9         1                3            2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# To get overall statistics about the dataset
data.describe()
# Out:
#              Age         Sex  ChestPainType   RestingBP  Cholesterol  \
# count  302.00000  302.000000     302.000000  302.000000   302.000000
# mean    54.42053    0.682119       0.963576  131.602649   246.500000
# std      9.04797    0.466426       1.032044   17.563394    51.753489
# min     29.00000    0.000000       0.000000   94.000000   126.000000
# 25%     48.00000    0.000000       0.000000  120.000000   211.000000
# 50%     55.50000    1.000000       1.000000  130.000000   240.500000
# 75%     61.00000    1.000000       2.000000  140.000000   274.750000
# max     77.00000    1.000000       3.000000  200.000000   564.000000
#
#         FastingBS  RestingECG       MaxHR  ExerciseAngina     Oldpeak  \
# count  302.000000  302.000000  302.000000      302.000000  302.000000
# mean     0.149007    0.526490  149.569536        0.327815    1.043046
# std      0.356686    0.526027   22.903527        0.470196    1.161452
# ...

# %%
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# To visualize the distribution of the target variable

# %%
sns.countplot(x='target', data=df,color='skyblue')

plt.xlabel('Target')  
plt.ylabel('Count')   
plt.title('Count Plot of Target')  

# Display the plot
plt.show()

# %%
# To find count of male & female in the dataset
sns.countplot(x='Sex', data=df,color='skyblue')

plt.xlabel('Sex')  # Set the x-axis label
plt.ylabel('Count')   # Set the y-axis label
plt.title('Count Plot of sex')  # Set the plot title

# Display the plot
plt.xticks([0,1],['Female','Male'])
plt.show()

# %% [markdown]
# Finding gender distribution according to the target variable

# %%
sns.countplot(x='Sex',hue="target",data=df)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# Checking age distribution in the dataset

# %%
sns.distplot(data['Age'],bins=20)
plt.show()
# Out:
# C:\Users\mohan\AppData\Local\Temp\ipykernel_18188\4138745824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],bins=20)

# %%
Checking pain types

# %%
sns.countplot(x='ChestPainType', data=df,color='skyblue')

plt.xlabel('ChestPainType')  # Set the x-axis label
plt.ylabel('Count')   # Set the y-axis label
plt.title('Count Plot of ChestPainType')  # Set the plot title

# Display the plot
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# showing the chest pain distribution as per the target variable

# %%
sns.countplot(x='ChestPainType',hue="target",data=df)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# showing fasting blood sugar distribution according to target variable

# %%
sns.countplot(x='FastingBS',hue="target",data=df)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# Feature Distribution: Visualizing the distribution of continuous features.

# %%
continuous_features = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']
df[continuous_features].hist(bins=30, figsize=(15, 10))
plt.suptitle('Distribution of Continuous Features')
plt.show()

# %% [markdown]
# Correlation Matrix: Examine the correlations between features and with the target variable.

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
Visualize relationships between features and the target variable

# %%
sns.pairplot(df, hue='target', vars=continuous_features)
plt.show()

# %%
for feature in continuous_features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='target', y=feature, data=df)
    plt.title(f'Boxplot of {feature} by Target')
    plt.show()

# %%
categorical_features = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'NumMajorVessels', 'Thalassemia']
for feature in categorical_features:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=feature, hue='target', data=df)
    plt.title(f'Countplot of {feature} by Target')
    plt.show()

# %%
Chi-square test: Assess the relationship between categorical features and the target variable.

# %%
from scipy.stats import chi2_contingency

for feature in categorical_features:
    contingency_table = pd.crosstab(df[feature], df['target'])
    chi2, p, dof, ex = chi2_contingency(contingency_table)
    print(f'Chi-square test for {feature}: chi2 = {chi2:.3f}, p-value = {p:.3f}')
# Out:
# Chi-square test for Sex: chi2 = 23.084, p-value = 0.000
# Chi-square test for ChestPainType: chi2 = 80.979, p-value = 0.000
# Chi-square test for FastingBS: chi2 = 0.092, p-value = 0.761
# Chi-square test for RestingECG: chi2 = 9.730, p-value = 0.008
# Chi-square test for ExerciseAngina: chi2 = 55.456, p-value = 0.000
# Chi-square test for ST_Slope: chi2 = 46.889, p-value = 0.000
# Chi-square test for NumMajorVessels: chi2 = 73.690, p-value = 0.000
# Chi-square test for Thalassemia: chi2 = 84.610, p-value = 0.000
